# %%
from brain_multimodal_vae.dataset.things_fmri import load_things_fmri_data

# %%
things_fmri_dir = "/home/acg17270jl/projects/brain-multimodal-vae/data/things_fmri/"
things_dir = "/home/acg17270jl/projects/brain-multimodal-vae/data/things/"
subject_list = ["x01"] # ["x01", "x02", "x03"]
roi_list = ['V1', 'V2', 'V3', 'hV4', 'VO1', 'VO2', 'LO1 (prf)', 'LO2 (prf)', 'TO1', 'TO2', 'V3b', 'V3a', 'lEBA', 'rEBA', 'lFFA', 'rFFA', 'lOFA', 'rOFA', 'lSTS', 'rSTS', 'lPPA', 'rPPA', 'lRSC', 'rRSC', 'lTOS', 'rTOS', 'lLOC', 'rLOC', 'IT']

# %%
train_brain_dict, train_label_dict, test_brain_dict, test_label_dict = load_things_fmri_data(things_fmri_dir, things_dir, subject_list, roi_list, label_mode="image", normalize=True, as_tensor=True)
